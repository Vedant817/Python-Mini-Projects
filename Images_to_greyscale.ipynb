# %%
import cv2
from skimage import io
import matplotlib.pyplot as plt

# %%
image=cv2.imread('/content/china.jpg')
plt.imshow(image)
cv2.waitKey(0)
# Out:
# -1

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray_image)
