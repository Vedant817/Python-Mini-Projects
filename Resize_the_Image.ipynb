# %%
import cv2
import matplotlib.pyplot as plt
from skimage import io

# %%
image = cv2.imread('/content/photo-1493976040374-85c8e12f0c0e.jpg')
smaller = cv2.resize(image, (0, 0), fx = 0.1, fy = 0.1)
plt.imshow(image)

# %%
# Another Approach
width=int(image.shape[1]*0.5)
height=int(image.shape[0]*0.5)
smaller2=cv2.resize(image,(width,height))

# %%
plt.imshow(smaller)

# %%
plt.imshow(smaller2)
cv2.waitKey(0)
cv2.destroyAllWindows()
